# %% [markdown]
# <a href="https://colab.research.google.com/github/juanmarcoszago44-sudo/Exerc-cios-da-disciplina-Introdu-o-Eng.-Computa-o-/blob/main/Untitled7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
idades = [25, 45, 18, 30, 22, 60, 52]

media = sum(idades) / len(idades)

print("Média das idades:", media)

print("Idades maiores que a média:")

for idade in idades:
    if idade > media:
        print(idade)
# Out:
# Média das idades: 36.0
# Idades maiores que a média:
# 45
# 60
# 52
