# %% [markdown]
# <a href="https://colab.research.google.com/github/juanmarcoszago44-sudo/Exerc-cios-da-disciplina-Introdu-o-Eng.-Computa-o-/blob/main/Aula%202.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
numero = int(input("Digite um número inteiro: "))

if numero > 0:
    print("Numero inteiro Positivo.")

elif numero < 0:
    print("Numero inteiro Negativo")

else:
    print("Numero igual a Zero")
# Out:
# Digite um número inteiro: -12
# Numero inteiro Negativo
