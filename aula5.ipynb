# %% [markdown]
# <a href="https://colab.research.google.com/github/juanmarcoszago44-sudo/Exerc-cios-da-disciplina-Introdu-o-Eng.-Computa-o-/blob/main/aula5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
contador = 1
print("Vai começar a contagem!")
while contador <= 10:
    print(f"Contagem: {contador}")
    contador = contador + 1

print("BOOOM!")
# Out:
# Vai começar a contagem!
# Contagem: 1
# Contagem: 2
# Contagem: 3
# Contagem: 4
# Contagem: 5
# Contagem: 6
# Contagem: 7
# Contagem: 8
# Contagem: 9
# Contagem: 10
# BOOOM!
