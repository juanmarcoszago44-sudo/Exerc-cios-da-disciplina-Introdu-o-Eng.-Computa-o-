# %% [markdown]
# <a href="https://colab.research.google.com/github/juanmarcoszago44-sudo/Exerc-cios-da-disciplina-Introdu-o-Eng.-Computa-o-/blob/main/Aula1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
peso = float(input("Digite o seu peso em KG:" ))
altura = float(input("Digite a sua altura em Metros:"))
imc = (peso / altura **2)

print (f"Seu IMC é: {imc:.2f}")
# Out:
# Digite o seu peso em KG:64
# Digite a sua altura em Metros:1.72
# Seu IMC é: 21.63
