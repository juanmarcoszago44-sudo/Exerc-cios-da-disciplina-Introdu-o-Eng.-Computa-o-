# %% [markdown]
# <a href="https://colab.research.google.com/github/juanmarcoszago44-sudo/Exerc-cios-da-disciplina-Introdu-o-Eng.-Computa-o-/blob/main/Aula3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
altura = float(input("Digite sua Altura:"))
idade = int(input("Digite sua Idade:"))
acompanhado = input("Está acompanhado dos pais? (sim/nao): ").lower()

if altura >= 1.50 and idade >= 12:
    print("Entrada liberada! 🎢")

elif altura >= 1.30 and acompanhado == "sim":
    print("Entrada liberada com os pais! 🎢")

else:
    print("Entrada NÃO permitida.")
# Out:
# Digite sua Altura:1.78
# Digite sua Idade:9
# Está acompanhado dos pais? (sim/nao): nao
# Entrada NÃO permitida.
